# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
alaska = pd.read_csv('question4_alaska.csv')
orlando = pd.read_csv('question4_O.csv')
ca = pd.read_csv('question4_CA.csv')
gc = pd.read_csv('question4_GC.csv')
no = pd.read_csv('question4_NO.csv')

# %%
alaska['mn'] = alaska['month'].astype(str).str[4:].astype(int)
alaska['month'] = alaska['month'].astype(str).str[:-2].astype(int)
alaska = alaska.groupby(['month','mn'], as_index=False).mean()
alaska

orlando['mn'] = orlando['month'].astype(str).str[4:].astype(int)
orlando['month'] = orlando['month'].astype(str).str[:-2].astype(int)
orlando = orlando.groupby(['month','mn'], as_index=False).mean()
orlando

ca['mn'] = ca['month'].astype(str).str[4:].astype(int)
ca['month'] = ca['month'].astype(str).str[:-2].astype(int)
ca = ca.groupby(['month','mn'], as_index=False).mean()
ca

gc['mn'] = gc['month'].astype(str).str[4:].astype(int)
gc['month'] = gc['month'].astype(str).str[:-2].astype(int)
gc = gc.groupby(['month','mn'], as_index=False).mean()

#no['mn'] = no['month'].astype(str).str[4:].astype(int)
#no['month'] = no['month'].astype(str).str[:-2].astype(int)
#no = no.groupby(['month','mn'], as_index=False).mean()
#no

# %%
df_alaska = []
for mn, sub_df in alaska.groupby('month',as_index=False):
    df_alaska.append(sub_df)
    
df_orlando = []
for mn, sub_df in orlando.groupby('month',as_index=False):
    df_orlando.append(sub_df)
    
df_ca = []
for mn, sub_df in ca.groupby('month',as_index=False):
    df_ca.append(sub_df)
    
df_gc = []
for mn, sub_df in ca.groupby('month',as_index=False):
    df_gc.append(sub_df)

    
df_no = []
for mn, sub_df in ca.groupby('month',as_index=False):
    df_no.append(sub_df)
    
months =['Jan','Feb','Mar','April','May','June','July','Aug','Sep','Oct','Nov','Dec']
months1 =['Aug','Sep','Oct','Nov','Dec']
months2 = ['Jan','Feb','Mar','April','May']
months3 =['Feb','Mar','April','May','July','Sep','Oct','Nov','Dec']
months4 =['Jan','Feb','Mar','April','May','June','July','Sep','Oct','Nov','Dec']
months5 =['Feb','Mar','April','May','July','Sep','Oct','Nov','Dec']
months6 =['Feb','Mar','April','May','July','Sep','Oct','Nov','Dec']

# %%
fig, [ax1,ax2]= plt.subplots(nrows=2, ncols=1,figsize=(10,8))
        

ax1.plot(months,df_gc[1]['precipitationAverage'], label=" 2011", color='blue',marker ='o')
ax1.plot(months5,df_gc[0]['precipitationAverage'], label="2010", color='red',marker ='o')
ax1.plot(months,df_gc[2]['precipitationAverage'], label=" 2012", color='teal',marker ='o')
ax1.plot(months,df_gc[3]['precipitationAverage'], label="2013", color='brown',marker ='o')
ax1.plot(months,df_gc[4]['precipitationAverage'], label=" 2014", color='indigo',marker ='o')
ax1.plot(months,df_gc[5]['precipitationAverage'], label="2015", color='orange',marker ='o')
ax1.plot(months,df_gc[6]['precipitationAverage'], label=" 2016", color='green',marker ='o')
ax1.plot(months,df_gc[7]['precipitationAverage'], label="2017", color='yellow',marker ='o')
ax1.plot(months4,df_gc[8]['precipitationAverage'], label=" 2018", color='cyan',marker ='o')
ax1.plot(months2,df_gc[9]['precipitationAverage'], label="2019", color='deepskyblue',marker ='o')
ax1.legend(loc = 'upper left', ncol=3, fancybox=True, shadow=True)
ax1.set_ylabel('Average Precipitation')
ax1.set_xlabel('Months')


ax2.plot(months,df_gc[1]['humidAverage'], label="2011", color='blue',marker ='o')
ax2.plot(months5,df_gc[0]['humidAverage'], label="2010", color='red',marker ='o')
ax2.plot(months,df_gc[2]['humidAverage'], label="2012", color='teal',marker ='o')
ax2.plot(months,df_gc[3]['humidAverage'], label="2013", color='brown',marker ='o')
ax2.plot(months,df_gc[4]['humidAverage'], label="2014", color='indigo',marker ='o')
ax2.plot(months,df_gc[5]['humidAverage'], label="2015", color='orange',marker ='o')
ax2.plot(months,df_gc[6]['humidAverage'], label="2016", color='green',marker ='o')
ax2.plot(months,df_gc[7]['humidAverage'], label="2017", color='yellow',marker ='o')
ax2.plot(months4,df_gc[8]['humidAverage'], label="2018", color='cyan',marker ='o')
ax2.plot(months2,df_gc[9]['humidAverage'], label="2019", color='deepskyblue',marker ='o')
ax2.legend(loc = 'lower left', ncol=3, fancybox=True, shadow=True)
ax2.set_ylabel('Average Humidity')
ax2.set_xlabel('Months')
#plt.savefig('question2_graph3.png')
# Out:
# Text(0.5, 0, 'Months')

# %%
fig, [ax1,ax2]= plt.subplots(nrows=2, ncols=1,figsize=(10,8))
        
ax1.plot(months,df_gc[1]['comfortIndex'], label="2011", color='blue',marker ='o')
ax1.plot(months5,df_gc[0]['comfortIndex'], label="2010", color='red',marker ='o')
ax1.plot(months,df_gc[2]['comfortIndex'], label="2012", color='teal',marker ='o')
ax1.plot(months,df_gc[3]['comfortIndex'], label="2013", color='brown',marker ='o')
ax1.plot(months,df_gc[4]['comfortIndex'], label="2014", color='indigo',marker ='o')
ax1.plot(months,df_gc[5]['comfortIndex'], label="2015", color='orange',marker ='o')
ax1.plot(months,df_gc[6]['comfortIndex'], label="2016", color='green',marker ='o')
ax1.plot(months,df_gc[7]['comfortIndex'], label="2017", color='yellow',marker ='o')
ax1.plot(months4,df_gc[8]['comfortIndex'], label="2018", color='cyan',marker ='o')
ax1.plot(months2,df_gc[9]['comfortIndex'], label="2019", color='deepskyblue',marker ='o')
ax1.legend(loc = 'lower right', ncol=2, fancybox=True, shadow=True)
ax1.set_ylabel('Average Comfort Index')
ax1.set_xlabel('Months')


ax2.plot(months,df_gc[1]['airTempAverage'], label="2011", color='blue',marker ='o')
ax2.plot(months5,df_gc[0]['airTempAverage'], label="2010", color='red',marker ='o')
ax2.plot(months,df_gc[2]['airTempAverage'], label="2012", color='teal',marker ='o')
ax2.plot(months,df_gc[3]['airTempAverage'], label="2013", color='brown',marker ='o')
ax2.plot(months,df_gc[4]['airTempAverage'], label="2014", color='indigo',marker ='o')
ax2.plot(months,df_gc[5]['airTempAverage'], label="2015", color='orange',marker ='o')
ax2.plot(months,df_gc[6]['airTempAverage'], label=" 2016", color='green',marker ='o')
ax2.plot(months,df_gc[7]['airTempAverage'], label="2017", color='yellow',marker ='o')
ax2.plot(months4,df_gc[8]['airTempAverage'], label=" 2018", color='cyan',marker ='o')
ax2.plot(months2,df_gc[9]['airTempAverage'], label="2019", color='deepskyblue',marker ='o')
ax2.legend(loc = 'upper left', ncol=2, fancybox=True, shadow=True)
ax2.set_ylabel('Average Air Temperature')
ax2.set_xlabel('Months')
#plt.savefig('question2_graph3.png')
# Out:
# Text(0.5, 0, 'Months')

# %%
fig, [ax1,ax2]= plt.subplots(nrows=2, ncols=1,figsize=(10,8))
        
ax1.plot(months,df_no[1]['comfortIndex'], label="2011", color='blue',marker ='o')
ax1.plot(months6,df_no[0]['comfortIndex'], label="2010", color='red',marker ='o')
ax1.plot(months,df_no[2]['comfortIndex'], label="2012", color='teal',marker ='o')
ax1.plot(months,df_no[3]['comfortIndex'], label="2013", color='brown',marker ='o')
ax1.plot(months,df_no[4]['comfortIndex'], label="2014", color='indigo',marker ='o')
ax1.plot(months,df_no[5]['comfortIndex'], label="2015", color='orange',marker ='o')
ax1.plot(months,df_no[6]['comfortIndex'], label="2016", color='green',marker ='o')
ax1.plot(months,df_no[7]['comfortIndex'], label="2017", color='yellow',marker ='o')
ax1.plot(months4,df_no[8]['comfortIndex'], label="2018", color='cyan',marker ='o')
ax1.plot(months2,df_no[9]['comfortIndex'], label="2019", color='deepskyblue',marker ='o')
ax1.legend(loc = 'lower right', ncol=4, fancybox=True, shadow=True)
ax1.set_ylabel('Average Comfort Index')
ax1.set_xlabel('Months')


ax2.plot(months,df_no[1]['airTempAverage'], label="2011", color='blue',marker ='o')
ax2.plot(months6,df_no[0]['airTempAverage'], label="2010", color='red',marker ='o')
ax2.plot(months,df_no[2]['airTempAverage'], label="2012", color='teal',marker ='o')
ax2.plot(months,df_no[3]['airTempAverage'], label="2013", color='brown',marker ='o')
ax2.plot(months,df_no[4]['airTempAverage'], label="2014", color='indigo',marker ='o')
ax2.plot(months,df_no[5]['airTempAverage'], label="2015", color='orange',marker ='o')
ax2.plot(months,df_no[6]['airTempAverage'], label=" 2016", color='green',marker ='o')
ax2.plot(months,df_no[7]['airTempAverage'], label="2017", color='yellow',marker ='o')
ax2.plot(months4,df_no[8]['airTempAverage'], label=" 2018", color='cyan',marker ='o')
ax2.plot(months2,df_no[9]['airTempAverage'], label="2019", color='deepskyblue',marker ='o')
ax2.legend(loc = 'upper left', ncol=2, fancybox=True, shadow=True)
ax2.set_ylabel('Average Air Temperature')
ax2.set_xlabel('Months')
plt.savefig('question4_no1.png')

# %%
fig, [ax1,ax2]= plt.subplots(nrows=2, ncols=1,figsize=(10,8))
        

ax1.plot(months,df_no[1]['precipitationAverage'], label=" 2011", color='blue',marker ='o')
ax1.plot(months6,df_no[0]['precipitationAverage'], label="2010", color='red',marker ='o')
ax1.plot(months,df_no[2]['precipitationAverage'], label=" 2012", color='teal',marker ='o')
ax1.plot(months,df_no[3]['precipitationAverage'], label="2013", color='brown',marker ='o')
ax1.plot(months,df_no[4]['precipitationAverage'], label=" 2014", color='indigo',marker ='o')
ax1.plot(months,df_no[5]['precipitationAverage'], label="2015", color='orange',marker ='o')
ax1.plot(months,df_no[6]['precipitationAverage'], label=" 2016", color='green',marker ='o')
ax1.plot(months,df_no[7]['precipitationAverage'], label="2017", color='yellow',marker ='o')
ax1.plot(months4,df_no[8]['precipitationAverage'], label=" 2018", color='cyan',marker ='o')
ax1.plot(months2,df_no[9]['precipitationAverage'], label="2019", color='deepskyblue',marker ='o')
ax1.legend(loc = 'upper left', ncol=3, fancybox=True, shadow=True)
ax1.set_ylabel('Average Precipitation')
ax1.set_xlabel('Months')


ax2.plot(months,df_no[1]['humidAverage'], label="2011", color='blue',marker ='o')
ax2.plot(months6,df_no[0]['humidAverage'], label="2010", color='red',marker ='o')
ax2.plot(months,df_no[2]['humidAverage'], label="2012", color='teal',marker ='o')
ax2.plot(months,df_no[3]['humidAverage'], label="2013", color='brown',marker ='o')
ax2.plot(months,df_no[4]['humidAverage'], label="2014", color='indigo',marker ='o')
ax2.plot(months,df_no[5]['humidAverage'], label="2015", color='orange',marker ='o')
ax2.plot(months,df_no[6]['humidAverage'], label="2016", color='green',marker ='o')
ax2.plot(months,df_no[7]['humidAverage'], label="2017", color='yellow',marker ='o')
ax2.plot(months4,df_no[8]['humidAverage'], label="2018", color='cyan',marker ='o')
ax2.plot(months2,df_no[9]['humidAverage'], label="2019", color='deepskyblue',marker ='o')
ax2.legend(loc = 'lower left', ncol=3, fancybox=True, shadow=True)
ax2.set_ylabel('Average Humidity')
ax2.set_xlabel('Months')
plt.savefig('question4_no2.png')

# %%
fig, [ax1,ax2]= plt.subplots(nrows=2, ncols=1,figsize=(10,8))
        

ax1.plot(months,df_alaska[1]['precipitationAverage'], label=" 2011", color='blue',marker ='o')
ax1.plot(months1,df_alaska[0]['precipitationAverage'], label="2010", color='red',marker ='o')
ax1.plot(months,df_alaska[2]['precipitationAverage'], label=" 2012", color='teal',marker ='o')
ax1.plot(months,df_alaska[3]['precipitationAverage'], label="2013", color='brown',marker ='o')
ax1.plot(months,df_alaska[4]['precipitationAverage'], label=" 2014", color='indigo',marker ='o')
ax1.plot(months,df_alaska[5]['precipitationAverage'], label="2015", color='orange',marker ='o')
ax1.plot(months,df_alaska[6]['precipitationAverage'], label=" 2016", color='green',marker ='o')
ax1.plot(months,df_alaska[7]['precipitationAverage'], label="2017", color='yellow',marker ='o')
ax1.plot(months,df_alaska[8]['precipitationAverage'], label=" 2018", color='cyan',marker ='o')
ax1.plot(months2,df_alaska[9]['precipitationAverage'], label="2019", color='deepskyblue',marker ='o')
ax1.legend(loc = 'upper left', ncol=3, fancybox=True, shadow=True)
ax1.set_ylabel('Average Precipitation')
ax1.set_xlabel('Months')


ax2.plot(months,df_alaska[1]['humidAverage'], label="2011", color='blue',marker ='o')
ax2.plot(months1,df_alaska[0]['humidAverage'], label="2010", color='red',marker ='o')
ax2.plot(months,df_alaska[2]['humidAverage'], label="2012", color='teal',marker ='o')
ax2.plot(months,df_alaska[3]['humidAverage'], label="2013", color='brown',marker ='o')
ax2.plot(months,df_alaska[4]['humidAverage'], label="2014", color='indigo',marker ='o')
ax2.plot(months,df_alaska[5]['humidAverage'], label="2015", color='orange',marker ='o')
ax2.plot(months,df_alaska[6]['humidAverage'], label="2016", color='green',marker ='o')
ax2.plot(months,df_alaska[7]['humidAverage'], label="2017", color='yellow',marker ='o')
ax2.plot(months,df_alaska[8]['humidAverage'], label="2018", color='cyan',marker ='o')
ax2.plot(months2,df_alaska[9]['humidAverage'], label="2019", color='deepskyblue',marker ='o')
ax2.legend(loc = 'upper left', ncol=3, fancybox=True, shadow=True)
ax2.set_ylabel('Average Humidity')
ax2.set_xlabel('Months')
#plt.savefig('question2_graph3.png')
# Out:
# Text(0.5, 0, 'Months')

# %%
fig, [ax1,ax2]= plt.subplots(nrows=2, ncols=1,figsize=(10,8))
        
ax1.plot(months,df_alaska[1]['comfortIndex'], label="2011", color='blue',marker ='o')
ax1.plot(months1,df_alaska[0]['comfortIndex'], label="2010", color='red',marker ='o')
ax1.plot(months,df_alaska[2]['comfortIndex'], label="2012", color='teal',marker ='o')
ax1.plot(months,df_alaska[3]['comfortIndex'], label="2013", color='brown',marker ='o')
ax1.plot(months,df_alaska[4]['comfortIndex'], label="2014", color='indigo',marker ='o')
ax1.plot(months,df_alaska[5]['comfortIndex'], label="2015", color='orange',marker ='o')
ax1.plot(months,df_alaska[6]['comfortIndex'], label="2016", color='green',marker ='o')
ax1.plot(months,df_alaska[7]['comfortIndex'], label="2017", color='yellow',marker ='o')
ax1.plot(months,df_alaska[8]['comfortIndex'], label="2018", color='cyan',marker ='o')
ax1.plot(months2,df_alaska[9]['comfortIndex'], label="2019", color='deepskyblue',marker ='o')
ax1.legend(loc = 'upper left', ncol=2, fancybox=True, shadow=True)
ax1.set_ylabel('Average Comfort Index')
ax1.set_xlabel('Months')


ax2.plot(months,df_alaska[1]['airTempAverage'], label="2011", color='blue',marker ='o')
ax2.plot(months1,df_alaska[0]['airTempAverage'], label="2010", color='red',marker ='o')
ax2.plot(months,df_alaska[2]['airTempAverage'], label="2012", color='teal',marker ='o')
ax2.plot(months,df_alaska[3]['airTempAverage'], label="2013", color='brown',marker ='o')
ax2.plot(months,df_alaska[4]['airTempAverage'], label="2014", color='indigo',marker ='o')
ax2.plot(months,df_alaska[5]['airTempAverage'], label="2015", color='orange',marker ='o')
ax2.plot(months,df_alaska[6]['airTempAverage'], label=" 2016", color='green',marker ='o')
ax2.plot(months,df_alaska[7]['airTempAverage'], label="2017", color='yellow',marker ='o')
ax2.plot(months,df_alaska[8]['airTempAverage'], label=" 2018", color='cyan',marker ='o')
ax2.plot(months2,df_alaska[9]['airTempAverage'], label="2019", color='deepskyblue',marker ='o')
ax2.legend(loc = 'upper left', ncol=2, fancybox=True, shadow=True)
ax2.set_ylabel('Average Air Temperature')
ax2.set_xlabel('Months')
#plt.savefig('question2_graph3.png')
# Out:
# Text(0.5, 0, 'Months')

# %%
fig, [ax1,ax2]= plt.subplots(nrows=2, ncols=1,figsize=(10,8))
        
ax1.plot(months,df_orlando[0]['precipitationAverage'], label=" 2010", color='blue',marker ='o')
ax1.plot(months,df_orlando[1]['precipitationAverage'], label="2011", color='red',marker ='o')
ax1.plot(months,df_orlando[2]['precipitationAverage'], label=" 2012", color='teal',marker ='o')
ax1.plot(months,df_orlando[3]['precipitationAverage'], label="2013", color='brown',marker ='o')
ax1.plot(months,df_orlando[4]['precipitationAverage'], label=" 2014", color='indigo',marker ='o')
ax1.plot(months,df_orlando[5]['precipitationAverage'], label="2015", color='orange',marker ='o')
ax1.plot(months,df_orlando[6]['precipitationAverage'], label=" 2016", color='green',marker ='o')
ax1.plot(months,df_orlando[7]['precipitationAverage'], label="2017", color='yellow',marker ='o')
ax1.plot(months,df_orlando[8]['precipitationAverage'], label=" 2018", color='cyan',marker ='o')
ax1.plot(months2,df_orlando[9]['precipitationAverage'], label="2019", color='deepskyblue',marker ='o')
ax1.legend(loc = 'upper left', ncol=3, fancybox=True, shadow=True)
ax1.set_ylabel('Average Precipitation')
ax1.set_xlabel('Months')

ax2.plot(months,df_orlando[0]['humidAverage'], label=" 2010", color='blue',marker ='o')
ax2.plot(months,df_orlando[1]['humidAverage'], label="2011", color='red',marker ='o')
ax2.plot(months,df_orlando[2]['humidAverage'], label=" 2012", color='teal',marker ='o')
ax2.plot(months,df_orlando[3]['humidAverage'], label="2013", color='brown',marker ='o')
ax2.plot(months,df_orlando[4]['humidAverage'], label=" 2014", color='indigo',marker ='o')
ax2.plot(months,df_orlando[5]['humidAverage'], label="2015", color='orange',marker ='o')
ax2.plot(months,df_orlando[6]['humidAverage'], label=" 2016", color='green',marker ='o')
ax2.plot(months,df_orlando[7]['humidAverage'], label="2017", color='yellow',marker ='o')
ax2.plot(months,df_orlando[8]['humidAverage'], label=" 2018", color='cyan',marker ='o')
ax2.plot(months2,df_orlando[9]['humidAverage'], label="2019", color='deepskyblue',marker ='o')
ax2.legend(loc = 'lower left', ncol=3, fancybox=True, shadow=True)
ax2.set_ylabel('Average Humidity')
ax2.set_xlabel('Months')
#plt.savefig('question2_graph3.png')
# Out:
# Text(0.5, 0, 'Months')

# %%
fig, [ax1,ax2]= plt.subplots(nrows=2, ncols=1,figsize=(10,8))
        
ax1.plot(months,df_orlando[0]['comfortIndex'], label=" 2010", color='blue',marker ='o')
ax1.plot(months,df_orlando[1]['comfortIndex'], label="2011", color='red',marker ='o')
ax1.plot(months,df_orlando[2]['comfortIndex'], label=" 2012", color='teal',marker ='o')
ax1.plot(months,df_orlando[3]['comfortIndex'], label="2013", color='brown',marker ='o')
ax1.plot(months,df_orlando[4]['comfortIndex'], label=" 2014", color='indigo',marker ='o')
ax1.plot(months,df_orlando[5]['comfortIndex'], label="2015", color='orange',marker ='o')
ax1.plot(months,df_orlando[6]['comfortIndex'], label=" 2016", color='green',marker ='o')
ax1.plot(months,df_orlando[7]['comfortIndex'], label="2017", color='yellow',marker ='o')
ax1.plot(months,df_orlando[8]['comfortIndex'], label=" 2018", color='cyan',marker ='o')
ax1.plot(months2,df_orlando[9]['comfortIndex'], label="2019", color='deepskyblue',marker ='o')
ax1.legend(loc = 'upper left', ncol=3, fancybox=True, shadow=True)
ax1.set_ylabel('Average Comfort Index')
ax1.set_xlabel('Months')

ax2.plot(months,df_orlando[0]['airTempAverage'], label=" 2010", color='blue',marker ='o')
ax2.plot(months,df_orlando[1]['airTempAverage'], label="2011", color='red',marker ='o')
ax2.plot(months,df_orlando[2]['airTempAverage'], label=" 2012", color='teal',marker ='o')
ax2.plot(months,df_orlando[3]['airTempAverage'], label="2013", color='brown',marker ='o')
ax2.plot(months,df_orlando[4]['airTempAverage'], label=" 2014", color='indigo',marker ='o')
ax2.plot(months,df_orlando[5]['airTempAverage'], label="2015", color='orange',marker ='o')
ax2.plot(months,df_orlando[6]['airTempAverage'], label=" 2016", color='green',marker ='o')
ax2.plot(months,df_orlando[7]['airTempAverage'], label="2017", color='yellow',marker ='o')
ax2.plot(months,df_orlando[8]['airTempAverage'], label=" 2018", color='cyan',marker ='o')
ax2.plot(months2,df_orlando[9]['airTempAverage'], label="2019", color='deepskyblue',marker ='o')
ax2.legend(loc = 'upper left', ncol=3, fancybox=True, shadow=True)
ax2.set_ylabel('Average Air Temperature')
ax2.set_xlabel('Months')
#plt.savefig('question2_graph3.png')
# Out:
# Text(0.5, 0, 'Months')

# %%
fig, [ax1,ax2]= plt.subplots(nrows=2, ncols=1,figsize=(10,8))
        

ax1.plot(months,df_ca[1]['precipitationAverage'], label="2011", color='red',marker ='o')
ax1.plot(months3,df_ca[0]['precipitationAverage'], label=" 2010", color='blue',marker ='o')
ax1.plot(months,df_ca[2]['precipitationAverage'], label=" 2012", color='teal',marker ='o')
ax1.plot(months,df_ca[3]['precipitationAverage'], label="2013", color='brown',marker ='o')
ax1.plot(months,df_ca[4]['precipitationAverage'], label=" 2014", color='indigo',marker ='o')
ax1.plot(months,df_ca[5]['precipitationAverage'], label="2015", color='orange',marker ='o')
ax1.plot(months,df_ca[6]['precipitationAverage'], label=" 2016", color='green',marker ='o')
ax1.plot(months,df_ca[7]['precipitationAverage'], label="2017", color='yellow',marker ='o')
ax1.plot(months4,df_ca[8]['precipitationAverage'], label=" 2018", color='cyan',marker ='o')
ax1.plot(months2,df_ca[9]['precipitationAverage'], label="2019", color='deepskyblue',marker ='o')
ax1.legend(loc = 'upper left', ncol=3, fancybox=True, shadow=True)
ax1.set_ylabel('Average Precipitation')
ax1.set_xlabel('Months')

ax2.plot(months,df_ca[1]['humidAverage'], label="2011", color='red',marker ='o')
ax2.plot(months3,df_ca[0]['humidAverage'], label=" 2010", color='blue',marker ='o')
ax2.plot(months,df_ca[2]['humidAverage'], label=" 2012", color='teal',marker ='o')
ax2.plot(months,df_ca[3]['humidAverage'], label="2013", color='brown',marker ='o')
ax2.plot(months,df_ca[4]['humidAverage'], label=" 2014", color='indigo',marker ='o')
ax2.plot(months,df_ca[5]['humidAverage'], label="2015", color='orange',marker ='o')
ax2.plot(months,df_ca[6]['humidAverage'], label=" 2016", color='green',marker ='o')
ax2.plot(months,df_ca[7]['humidAverage'], label="2017", color='yellow',marker ='o')
ax2.plot(months4,df_ca[8]['humidAverage'], label=" 2018", color='cyan',marker ='o')
ax2.plot(months2,df_ca[9]['humidAverage'], label="2019", color='deepskyblue',marker ='o')
ax2.legend(loc = 'lower left', ncol=3, fancybox=True, shadow=True)
ax2.set_ylabel('Average Humidity')
ax2.set_xlabel('Months')
#plt.savefig('question2_graph3.png')
# Out:
# Text(0.5, 0, 'Months')

# %%
fig, [ax1,ax2]= plt.subplots(nrows=2, ncols=1,figsize=(10,8))
        
ax1.plot(months,df_ca[1]['comfortIndex'], label="2011", color='red',marker ='o')
ax1.plot(months3,df_ca[0]['comfortIndex'], label=" 2010", color='blue',marker ='o')
ax1.plot(months,df_ca[2]['comfortIndex'], label=" 2012", color='teal',marker ='o')
ax1.plot(months,df_ca[3]['comfortIndex'], label="2013", color='brown',marker ='o')
ax1.plot(months,df_ca[4]['comfortIndex'], label=" 2014", color='indigo',marker ='o')
ax1.plot(months,df_ca[5]['comfortIndex'], label="2015", color='orange',marker ='o')
ax1.plot(months,df_ca[6]['comfortIndex'], label=" 2016", color='green',marker ='o')
ax1.plot(months,df_ca[7]['comfortIndex'], label="2017", color='yellow',marker ='o')
ax1.plot(months4,df_ca[8]['comfortIndex'], label=" 2018", color='cyan',marker ='o')
ax1.plot(months2,df_ca[9]['comfortIndex'], label="2019", color='deepskyblue',marker ='o')
ax1.legend(loc = 'lower right', ncol=3, fancybox=True, shadow=True)
ax1.set_ylabel('Average Comfort Index')
ax1.set_xlabel('Months')

ax2.plot(months,df_ca[1]['airTempAverage'], label="2011", color='red',marker ='o')
ax2.plot(months3,df_ca[0]['airTempAverage'], label=" 2010", color='blue',marker ='o')
ax2.plot(months,df_ca[2]['airTempAverage'], label=" 2012", color='teal',marker ='o')
ax2.plot(months,df_ca[3]['airTempAverage'], label="2013", color='brown',marker ='o')
ax2.plot(months,df_ca[4]['airTempAverage'], label=" 2014", color='indigo',marker ='o')
ax2.plot(months,df_ca[5]['airTempAverage'], label="2015", color='orange',marker ='o')
ax2.plot(months,df_ca[6]['airTempAverage'], label=" 2016", color='green',marker ='o')
ax2.plot(months,df_ca[7]['airTempAverage'], label="2017", color='yellow',marker ='o')
ax2.plot(months4,df_ca[8]['airTempAverage'], label=" 2018", color='cyan',marker ='o')
ax2.plot(months2,df_ca[9]['airTempAverage'], label="2019", color='deepskyblue',marker ='o')
ax2.legend(loc = 'upper left', ncol=3, fancybox=True, shadow=True)
ax2.set_ylabel('Average Air Temperature')
ax2.set_xlabel('Months')
#plt.savefig('question2_graph3.png')
# Out:
# Text(0.5, 0, 'Months')
