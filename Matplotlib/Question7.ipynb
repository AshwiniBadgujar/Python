# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('question7.csv')

# %%
corr = data.corr()
corr
# Out:
#                 air_temp  precipitation      solar  surface_temp  humidity  \
# air_temp        1.000000       -0.491481  0.483443      0.986880  0.250260
# precipitation  -0.491481        1.000000 -0.519381     -0.506501 -0.416851
# solar           0.483443       -0.519381  1.000000      0.614004  0.442097
# surface_temp    0.986880       -0.506501  0.614004      1.000000  0.291297
# humidity        0.250260       -0.416851  0.442097      0.291297  1.000000
# wetness         0.163564       -0.308232  0.022966      0.138271  0.060478
# wind           -0.433705       -0.299167 -0.365608     -0.477324 -0.401052
#
#                  wetness      wind
# air_temp        0.163564 -0.433705
# precipitation  -0.308232 -0.299167
# solar           0.022966 -0.365608
# surface_temp    0.138271 -0.477324
# humidity        0.060478 -0.401052
# wetness         1.000000 -0.116909
# wind           -0.116909  1.000000

# %%
plt.figure(figsize=(15,10))
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
  #  cmap = sns.cubehelix_palette(8),
  #  cmap = sns.diverging_palette(255, 133, l=60, n=7, center="dark"),
    cmap = sns.color_palette("Blues"),
    linewidths=2, linecolor='white',
    square=True,
    annot=True
)
b, t = plt.ylim() # discover the values for bottom and top
b += 0.5 # Add 0.5 to the bottom
t -= 0.5 # Subtract 0.5 from the top
plt.ylim(b, t) # update the ylim(bottom, top) values
#plt.show() # ta-da!
#ax.set_xticklabels(
#    ax.get_xticklabels(),
#   rotation=45,
#    horizontalalignment='right'
#);
plt.savefig('question7_2.png')
