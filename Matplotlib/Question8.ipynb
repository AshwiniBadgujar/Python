# %%
import pandas as pd
import matplotlib.pyplot as plt
from dateutil.parser import parse
import matplotlib.dates as mdates
import numpy as np

# %%
question8 = pd.read_csv('question8.csv')
il = pd.read_csv('il.csv')
il
ind = pd.read_csv('in.csv')
iowa = pd.read_csv('lowa.csv')
iowa
kan = pd.read_csv('kan.csv')
kan
mi = pd.read_csv('mi.csv')
mi
mis = pd.read_csv('mis.csv')
mis
nd = pd.read_csv('nd.csv')
nd
nb = pd.read_csv('nb.csv')
nb
oh = pd.read_csv('oh.csv')
nd
# Out:
#      region      year  maxAirTemp  airTempAverage  solarRadiation  \
# 0       c8q  20060801        25.5    -2031.747200               0
# 1       c8q  20060802        29.9    -1685.454500               0
# 2       c8q  20060803        32.7       22.709026               0
# 3       c8q  20060804        35.2       25.289932               0
# 4       c8q  20060805        33.3       24.268394               0
# ...     ...       ...         ...             ...             ...
# 1111    c8x  20180830        31.1       20.455210               0
# 1112    cb3  20180830        27.5       19.128473               0
# 1113    c8q  20180831        29.2       21.588898               0
# 1114    c8x  20180831        27.4       17.407986               0
# 1115    cb3  20180831        28.8       21.429520               0
#
#       average_air_temperature
# 0                          29
# 1                          29
# 2                          29
# 3                          29
# ...

# %%
il['year'] = il['year'].astype(str)
il.index = pd.to_datetime([parse(d).strftime('%Y-%m-%d') for d in il['year']])
il
ind['year'] = ind['year'].astype(str)
ind.index = pd.to_datetime([parse(d).strftime('%Y-%m-%d') for d in ind['year']])
ind
iowa['year'] = iowa['year'].astype(str)
iowa.index = pd.to_datetime([parse(d).strftime('%Y-%m-%d') for d in iowa['year']])
iowa
kan['year'] = kan['year'].astype(str)
kan.index = pd.to_datetime([parse(d).strftime('%Y-%m-%d') for d in kan['year']])
kan
mi['year'] = mi['year'].astype(str)
mi.index = pd.to_datetime([parse(d).strftime('%Y-%m-%d') for d in mi['year']])
mi
mis['year'] = mis['year'].astype(str)
mis.index = pd.to_datetime([parse(d).strftime('%Y-%m-%d') for d in mis['year']])
mis
nd['year'] = nd['year'].astype(str)
nd.index = pd.to_datetime([parse(d).strftime('%Y-%m-%d') for d in nd['year']])
nd
nb['year'] = nb['year'].astype(str)
nb.index = pd.to_datetime([parse(d).strftime('%Y-%m-%d') for d in nb['year']])
nb
oh['year'] = oh['year'].astype(str)
oh.index = pd.to_datetime([parse(d).strftime('%Y-%m-%d') for d in oh['year']])
oh
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-492-731ce5ee230a> in <module>
#      24 nb
#      25 oh['year'] = oh['year'].astype(str)
# ---> 26 oh.index = pd.to_datetime([parse(d).strftime('%Y-%m-%d') for d in oh['year']])
#      27 oh
#
# <ipython-input-492-731ce5ee230a> in <listcomp>(.0)
#      24 nb
#      25 oh['year'] = oh['year'].astype(str)
# ---> 26 oh.index = pd.to_datetime([parse(d).strftime('%Y-%m-%d') for d in oh['year']])
#      27 oh
#
# c:\users\ashwi\appdata\local\programs\python\python37\lib\site-packages\dateutil\parser\_parser.py in parse(timestr, parserinfo, **kwargs)
#    1356         return parser(parserinfo).parse(timestr, **kwargs)
#    1357     else:
# -> 1358         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1359
#    1360
#
# ...

# %%
ind1 = ind[ind['year'] >= '20120801']

# %%
#years = mdates.YearLocator() 
months = [2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018]

colors = np.random.rand(403)
ax1 = il.plot(figsize=(20,10),x='year', y=['maxAirTemp','average_air_temperature'] ,grid = True,linewidth = 4)

plt.xlabel('Year');
plt.ylabel('Air Temperatue')
plt.savefig('question8_temp_illinois.png')

# %%
#years = mdates.YearLocator() 
months = [2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018]

colors = np.random.rand(403)
ax1 = ind.plot(figsize=(20,10),x='year', y=['maxAirTemp','average_air_temperature'] ,grid = True,linewidth = 4)

plt.xlabel('Year');
plt.ylabel('Air Temperatue')
plt.savefig('question8_temp_indiana.png')

# %%
#years = mdates.YearLocator() 
months = [2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018]

colors = np.random.rand(403)
ax1 = iowa.plot(figsize=(20,10),x='year', y=['maxAirTemp','average_air_temperature'] ,grid = True,linewidth = 4)

plt.xlabel('Year');
plt.ylabel('Air Temperatue')
plt.savefig('question8_temp_iowa.png')

# %%
months = [2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018]

colors = np.random.rand(403)
ax1 = kan.plot(figsize=(20,10),x='year', y=['maxAirTemp','average_air_temperature'] ,grid = True,linewidth = 4)

plt.xlabel('Year');
plt.ylabel('Air Temperatue')
plt.savefig('question8_temp_kansas.png')

# %%
months = [2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018]

colors = np.random.rand(403)
ax1 = mi.plot(figsize=(20,10),x='year', y=['maxAirTemp','average_air_temperature'] ,grid = True,linewidth = 4)

plt.xlabel('Year');
plt.ylabel('Air Temperatue')
plt.savefig('question8_temp_miness.png')

# %%
colors = np.random.rand(403)
ax1 = mis.plot(figsize=(20,10),x='year', y=['maxAirTemp','average_air_temperature'] ,grid = True,linewidth = 4)

plt.xlabel('Year');
plt.ylabel('Air Temperatue')
plt.savefig('question8_temp_missouri.png')

# %%
colors = np.random.rand(403)
ax1 = nd.plot(figsize=(20,10),x='year', y=['maxAirTemp','average_air_temperature'] ,grid = True,linewidth = 4)

plt.xlabel('Year');
plt.ylabel('Air Temperatue')
plt.savefig('question8_temp_nd.png')

# %%
colors = np.random.rand(403)
ax1 = nb.plot(figsize=(20,10),x='year', y=['maxAirTemp','average_air_temperature'] ,grid = True,linewidth = 4)

plt.xlabel('Year');
plt.ylabel('Air Temperatue')
plt.savefig('question8_temp_nb.png')

# %%
colors = np.random.rand(403)
ax1 = oh.plot(figsize=(20,10),x='year', y=['maxAirTemp','average_air_temperature'] ,grid = True,linewidth = 4)

plt.xlabel('Year');
plt.ylabel('Air Temperatue')
plt.savefig('question8_temp_oh.png')

# %%
#xValues = Series.pd()'2008-08-01','2009-08-20','2011-08-08','2011-08-01','2012-08-27','2014-08-15','2016-08-03','2017-08-22']
labels = [20080801,20090820,20110808,20110801,20120827,20140815,20160803,20170822]
ys = [20080801,20090820,20110808,20110801,20120827,20140815,20160803,20170822]
area = (30 * np.random.rand(50))**2  # 0 to 15 point radii
fig, ax1 = plt.subplots(figsize=(15,6))
#ax1.figure(figsize=(15,10))
ax1.scatter(ind1['year'], ind1['solarRadiation'],s = area,color = 'orange', alpha = 0.3)
ax1.set_xticks(ax1.get_xticks()[::20])
#t.xticks(rotation='vertical')
#plt.setp(labels, rotation=90)
#plt.set_title('Solar Radiation')
#plt.xticks(labels)
#ax1.set_xticks(xValues, minor=True)

#ax1.get_xaxis().set_ticks([20120827])
#plt.xticks([20080801,20090820,20110808,20110801,20120827,20140815,20160803,20170822],rotation=90)
plt.savefig('question8_solar_il.png')

# %%
labels = [20080801,20090820,20110808,20110801,20120827,20140815,20160803,20170822]
ys = [20080801,20090820,20110808,20110801,20120827,20140815,20160803,20170822]
area = (30 * np.random.rand(50))**2  # 0 to 15 point radii
fig, ax1 = plt.subplots(figsize=(15,6))
#ax1.figure(figsize=(15,10))
ax1.scatter(ind1['year'], ind1['solarRadiation'],s = area,color = 'orange', alpha = 0.3)
ax1.set_xticks(ax1.get_xticks()[::20])
#t.xticks(rotation='vertical')
#plt.setp(labels, rotation=90)
#plt.set_title('Solar Radiation')
#plt.xticks(labels)
#ax1.set_xticks(xValues, minor=True)

#ax1.get_xaxis().set_ticks([20120827])
#plt.xticks([20080801,20090820,20110808,20110801,20120827,20140815,20160803,20170822],rotation=90)
plt.savefig('question8_solar_il.png')

# %%
fig, ax = plt.subplots(figsize=(12,10))

size = 0.5
#vals = np.array([[60., 32.], [37., 40.], [29., 10.]])

cmap = plt.get_cmap("tab20c")
inner_colors = []
labels = question8['area']
sizes = question8['acre']
#inner_colors = ['#451e3e','#573451','#6a4a64','#7c6177','#8f788b','#a28e9e','#b4a5b1','#c7bbc5','#d9d2d8','#ece8eb','#ffffff']
outer_colors = ['pink','orange','red','blue','green','maroon','deepskyblue']

ax.pie(sizes, radius=1, colors=outer_colors, labels = sizes,wedgeprops=dict(width=size, edgecolor='w'))

ax.set(aspect="equal", title='Acres')
plt.legend(labels,loc="lower right")
plt.savefig('pie.png')

# %%
fig, ax = plt.subplots(figsize=(12,10))

size = 0.5
#vals = np.array([[60., 32.], [37., 40.], [29., 10.]])

cmap = plt.get_cmap("tab20c")
inner_colors = []
labels = question8['area']
sizes = question8['production']
inner_colors = ['#451e3e','#573451','#6a4a64','#7c6177','#8f788b','#a28e9e','#b4a5b1','#c7bbc5','#d9d2d8','#ece8eb','#ffffff']
#outer_colors = ['pink','orange','red','blue','green','maroon','deepskyblue']

ax.pie(sizes, radius=1, colors=inner_colors, labels = sizes,wedgeprops=dict(width=size, edgecolor='w'))

ax.set(aspect="equal", title='Production')
plt.legend(labels,loc="lower right")
plt.savefig('pie2.png')
